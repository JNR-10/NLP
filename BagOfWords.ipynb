# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("spam.csv")
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.Category.value_counts()
# Out:
# ham     4825
# spam     747
# Name: Category, dtype: int64

# %%
df['spam'] = df['Category'].apply(lambda x: 1 if x =='spam' else 0)

# %%
df.shape
# Out:
# (5572, 3)

# %%
df.head()
# Out:
#   Category                                            Message  spam
# 0      ham  Go until jurong point, crazy.. Available only ...     0
# 1      ham                      Ok lar... Joking wif u oni...     0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3      ham  U dun say so early hor... U c already then say...     0
# 4      ham  Nah I don't think he goes to usf, he lives aro...     0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.Message, df.spam, test_size=0.2)

# %%
type(X_train)
# Out:
# pandas.core.series.Series

# %%
X_train[:4]
# Out:
# 3807    URGENT! We are trying to contact you. Last wee...
# 1981                               Sorry, I'll call later
# 4746    Camera - You are awarded a SiPix Digital Camer...
# 4099       I think just yourself …Thanks and see you tomo
# Name: Message, dtype: object

# %%
y_train[:4]
# Out:
# 3807    1
# 1981    0
# 4746    1
# 4099    0
# Name: spam, dtype: int64

# %%
X_train.values
# Out:
# array(['URGENT! We are trying to contact you. Last weekends draw shows that you have won a £900 prize GUARANTEED. Call 09061701851. Claim code K61. Valid 12hours only',
#        "Sorry, I'll call later",
#        'Camera - You are awarded a SiPix Digital Camera! call 09061221066 fromm landline. Delivery within 28 days.',
#        ...,
#        'Wen ur lovable bcums angry wid u, dnt take it seriously.. Coz being angry is d most childish n true way of showing deep affection, care n luv!.. kettoda manda... Have nice day da.',
#        "Sorry, I'll call later",
#        "As per your request 'Maangalyam (Alaipayuthe)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune"],
#       dtype=object)

# %%
type(X_train.values)
# Out:
# numpy.ndarray

# %%
## Create bag of words representation using CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

v = CountVectorizer()

X_train_cv = v.fit_transform(X_train.values)
X_train_cv
# Out:
# <4457x7717 sparse matrix of type '<class 'numpy.int64'>'
# 	with 59369 stored elements in Compressed Sparse Row format>

# %%
X_train_cv.toarray()[:2][0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
X_train_cv.shape
# Out:
# (4457, 7717)

# %%
v.get_feature_names_out()[1060]
# Out:
# 'arabian'

# %%
v.vocabulary_
# Out:
# {'urgent': 7189,
#  'we': 7396,
#  'are': 1064,
#  'trying': 7044,
#  'to': 6921,
#  'contact': 2010,
#  'you': 7678,
#  'last': 4043,
#  'weekends': 7417,
#  'draw': 2459,
#  'shows': 6137,
#  'that': 6795,
#  'have': 3377,
#  'won': 7547,
#  '900': 734,
#  'prize': 5430,
#  'guaranteed': 3283,
#  'call': 1617,
#  '09061701851': 202,
#  'claim': 1844,
#  'code': 1906,
#  'k61': 3906,
#  'valid': 7226,
#  '12hours': 302,
#  'only': 4954,
#  'sorry': 6329,
#  'll': 4176,
#  'later': 4049,
#  'camera': 1637,
#  'awarded': 1180,
#  'sipix': 6181,
#  'digital': 2338,
#  '09061221066': 199,
#  'fromm': 3038,
#  'landline': 4026,
#  'delivery': 2258,
#  'within': 7521,
#  '28': 387,
#  'days': 2209,
#  'think': 6830,
#  'just': 3899,
#  'yourself': 7689,
#  'thanks': 6789,
#  'and': 972,
#  'see': 5984,
#  'tomo': 6944,
#  'don': 2421,
#  'floppy': 2922,
#  'snappy': 6273,
#  'happy': 3354,
#  'gay': 3106,
#  'chat': 1760,
#  'service': 6031,
#  'with': 7518,
#  'photo': 5196,
#  'upload': 7177,
#  '08718730666': 151,
#  '10p': 280,
#  'min': 4498,
#  'stop': 6485,
#  'our': 5013,
#  'texts': 6783,
#  '08712460324': 111,
#  'hey': 3442,
#  'didntgive': 2324,
#  'ya': 7636,
#  'bellearlier': 1322,
#  'hunny': 3578,
#  'been': 1300,
#  'in': 3660,
#  'bedbut': 1294,
#  'mite': 4534,
#  'go': 3180,
#  'thepub': 6814,
#  'l8tr': 4005,
#  'if': 3624,
#  'uwana': 7217,
#  'mt': 4635,
#  'up': 7169,
#  'loads': 4181,
#  'luv': 4281,
#  'jenxxx': 3835,
#  'oclock': 4897,
#  'at': 1127,
#  'mine': 4503,
#  'bash': 1246,
#  'out': 5015,
#  'flat': 2905,
#  'plan': 5238,
#  'hahaha': 3317,
#  'use': 7202,
#  'your': 7684,
#  'brain': 1488,
#  'dear': 2217,
#  'for': 2959,
#  'ur': 7185,
#  'chance': 1736,
#  'win': 7494,
#  '250': 380,
#  'wkly': 7531,
#  'shopping': 6110,
#  'spree': 6408,
#  'txt': 7077,
#  'shop': 6108,
#  '80878': 661,
#  'www': 7613,
#  'com': 1928,
#  'custcare': 2152,
#  '08715705022': 130,
#  '1x150p': 354,
#  'wk': 7527,
#  'new': 4767,
#  'textbuddy': 6776,
#  'horny': 3523,
#  'guys': 3302,
#  'area': 1065,
#  '25p': 382,
#  'free': 3004,
#  'receive': 5626,
#  'search': 5968,
#  'postcode': 5341,
#  'or': 4980,
#  'gaytextbuddy': 3109,
#  'one': 4948,
#  'name': 4692,
#  '89693': 725,
#  '08715500022': 129,
#  'rpl': 5833,
#  'cnl': 1894,
#  'best': 1336,
#  'msg': 4628,
#  'it': 3780,
#  'hard': 3355,
#  'be': 1277,
#  'person': 5166,
#  'when': 7453,
#  'know': 3982,
#  'more': 4598,
#  'step': 6464,
#  'foward': 2990,
#  'will': 7491,
#  'make': 4340,
#  'fall': 2778,
#  'love': 4242,
#  'amp': 962,
#  'back': 1203,
#  'can': 1641,
#  'ruin': 5848,
#  'friendship': 3026,
#  'good': 3201,
#  'night': 4786,
#  'reckon': 5636,
#  'need': 4736,
#  'town': 6985,
#  'by': 1604,
#  'eightish': 2565,
#  'walk': 7344,
#  'from': 3037,
#  'carpark': 1681,
#  'dunno': 2506,
#  'da': 2169,
#  'next': 4774,
#  'show': 6129,
#  'aft': 862,
#  'is': 3769,
#  '850': 689,
#  'toa': 6922,
#  'payoh': 5131,
#  'got': 3217,
#  '650': 595,
#  'get': 3135,
#  'lions': 4154,
#  'england': 2614,
#  'tone': 6947,
#  'reply': 5713,
#  'lionm': 4152,
#  'mono': 4587,
#  'lionp': 4153,
#  'poly': 5299,
#  'ringtones': 5790,
#  'co': 1896,
#  'uk': 7105,
#  'the': 6799,
#  'original': 4997,
#  'tones': 6948,
#  '3gbp': 472,
#  'network': 4758,
#  'operator': 4968,
#  'rates': 5582,
#  'apply': 1039,
#  'oh': 4919,
#  'please': 5256,
#  'its': 3787,
#  'over': 5031,
#  'do': 2392,
#  'any': 1005,
#  'dislikes': 2373,
#  'bed': 1293,
#  'lei': 4093,
#  'he': 3387,
#  'neva': 4761,
#  'say': 5925,
#  'my': 4674,
#  'how': 3544,
#  'come': 1933,
#  'took': 6959,
#  'so': 6282,
#  'long': 4207,
#  'leave': 4081,
#  'zaher': 7703,
#  'words': 7560,
#  'on': 4943,
#  'ym': 7671,
#  'was': 7371,
#  'them': 6807,
#  'but': 1590,
#  'sad': 5872,
#  'had': 3313,
#  'left': 4086,
#  'miss': 4523,
#  'playin': 5251,
#  'space': 6348,
#  'poker': 5292,
#  'top': 6965,
#  'ringtone': 5788,
#  'sub': 6544,
#  'weekly': 7418,
#  '1st': 347,
#  'week': 7414,
#  'send': 6010,
#  'subpoly': 6548,
#  '81618': 665,
#  'per': 5151,
#  'sms': 6264,
#  '08718727870': 148,
#  'gorgeous': 3213,
#  'man': 4350,
#  'work': 7561,
#  'mobile': 4554,
#  'number': 4863,
#  'babe': 1197,
#  'squishy': 6416,
#  'mwahs': 4673,
#  'wet': 7445,
#  'right': 5779,
#  'now': 4851,
#  'true': 7035,
#  'easier': 2527,
#  'her': 3432,
#  'here': 3433,
#  'well': 7429,
#  'gonna': 3199,
#  'finish': 2878,
#  'bath': 1253,
#  'fine': 2875,
#  'take': 6681,
#  'us': 7199,
#  'mark': 4375,
#  'distract': 2378,
#  'isaiah': 3770,
#  'nope': 4826,
#  'forgot': 2971,
#  'panasonic': 5067,
#  'bluetoothhdset': 1417,
#  'nokia': 4813,
#  'motorola': 4612,
#  'doublemins': 2440,
#  'doubletxt': 2442,
#  'orange': 4982,
#  'contract': 2017,
#  'mobileupd8': 4558,
#  '08000839402': 49,
#  '2optout': 418,
#  'reach': 5595,
#  'orchard': 4984,
#  'already': 936,
#  'wan': 7354,
#  'buy': 1594,
#  'tickets': 6875,
#  'first': 2890,
#  'tried': 7024,
#  're': 5594,
#  'video': 7263,
#  '750': 628,
#  'mins': 4512,
#  'unlimited': 7154,
#  'text': 6772,
#  'camcorder': 1635,
#  '08000930705': 50,
#  'del': 2248,
#  'thurs': 6868,
#  'abeg': 762,
#  'profit': 5450,
#  'start': 6441,
#  'using': 7209,
#  'sponsors': 6398,
#  'event': 2677,
#  'desperate': 2289,
#  'armand': 1080,
#  'again': 869,
#  'private': 5428,
#  '2003': 359,
#  'account': 794,
#  'statement': 6449,
#  '07753741225': 30,
#  '800': 647,
#  'un': 7115,
#  'redeemed': 5647,
#  'points': 5291,
#  '08715203677': 125,
#  'identifier': 3618,
#  '42478': 498,
#  'expires': 2737,
#  '24': 376,
#  '10': 268,
#  '04': 14,
#  'great': 3255,
#  'should': 6122,
#  'whens': 7456,
#  'radio': 5553,
#  'whore': 7472,
#  'unbelievable': 7117,
#  'available': 1163,
#  'soiree': 6290,
#  'june': 3895,
#  '3rd': 480,
#  'log': 4192,
#  'off': 4900,
#  'wat': 7377,
#  'sdryb8i': 5965,
#  'has': 3363,
#  '2000': 358,
#  '09061790121': 211,
#  'land': 4024,
#  'line': 4142,
#  '3030': 441,
#  '12hrs': 303,
#  '150ppm': 323,
#  'thats': 6798,
#  'cool': 2033,
#  'where': 7457,
#  'cum': 2140,
#  'taste': 6702,
#  'fish': 2891,
#  'curry': 2148,
#  'nah': 4687,
#  'im': 3635,
#  'goin': 3190,
#  'wrks': 7596,
#  'wot': 7579,
#  'bout': 1461,
#  'badrith': 1208,
#  'chennai': 1785,
#  'surely': 6618,
#  'pick': 5204,
#  'no': 4805,
#  'competition': 1955,
#  'him': 3456,
#  'wiskey': 7516,
#  'brandy': 1494,
#  'rum': 5852,
#  'gin': 3155,
#  'beer': 1302,
#  'vodka': 7298,
#  'scotch': 5949,
#  'shampain': 6062,
#  'wine': 7501,
#  'kudi': 3998,
#  'yarasu': 7643,
#  'dhina': 2310,
#  'vaazhthukkal': 7220,
#  'problem': 5436,
#  'baby': 1200,
#  'this': 6839,
#  'time': 6886,
#  'talk': 6689,
#  'called': 1624,
#  'message': 4473,
#  'hi': 3446,
#  'darlin': 2193,
#  'helens': 3416,
#  'fone': 2948,
#  'princes': 5419,
#  'nite': 4800,
#  'tb': 6715,
#  'kate': 3922,
#  'yes': 7661,
#  'they': 6823,
#  'said': 5879,
#  'beautiful': 1284,
#  'tomorrow': 6946,
#  'never': 4763,
#  'comes': 1935,
#  'today': 6926,
#  'hunt': 3579,
#  'of': 4899,
#  'waste': 7375,
#  'wonderful': 7550,
#  'goodmorning': 3206,
#  'knock': 3980,
#  'whose': 7474,
#  'there': 6815,
#  '80082': 651,
#  'enter': 2624,
#  'gift': 3148,
#  'voucher': 7309,
#  'store': 6494,
#  'yr': 7692,
#  'choice': 1821,
#  'cs': 2118,
#  'tkls': 6908,
#  'age16': 872,
#  'stoptxtstop': 6493,
#  '50': 547,
#  'aah': 755,
#  'cuddle': 2136,
#  'would': 7583,
#  'lush': 4279,
#  'lots': 4232,
#  'tea': 6720,
#  'soup': 6340,
#  'before': 1306,
#  'kind': 3961,
#  'fumbling': 3059,
#  'going': 3192,
#  'xin': 7622,
#  'hostel': 3530,
#  'all': 923,
#  'innocent': 3704,
#  'fun': 3060,
#  'reality': 5606,
#  'fantasy': 2794,
#  '08707509020': 87,
#  '20p': 366,
#  'ntt': 4858,
#  'ltd': 4266,
#  'po': 5270,
#  'box': 1464,
#  '1327': 306,
#  'croydon': 2111,
#  'cr9': 2080,
#  '5wb': 578,
#  '0870': 71,
#  'national': 4711,
#  'rate': 5581,
#  'gr8': 3231,
#  '20': 356,
#  'phone': 5191,
#  'every': 2681,
#  'opt': 4975,
#  '08452810071': 68,
#  '16': 329,
#  'wish': 7511,
#  'semester': 6006,
#  'congratulations': 1997,
#  '500': 548,
#  'cd': 1709,
#  'vouchers': 7310,
#  '125gift': 301,
#  'entry': 2633,
#  '100': 269,
#  'music': 4664,
#  '87066': 700,
#  'tncs': 6920,
#  'ldew': 4067,
#  'com1win150ppmx3age16': 1929,
#  'general': 3121,
#  'price': 5413,
#  'lt': 4265,
#  'gt': 3280,
#  'oz': 5049,
#  'let': 4105,
#  'me': 4423,
#  'much': 4644,
#  'want': 7358,
#  'th': 6784,
#  'gower': 3228,
#  'mate': 4398,
#  'which': 7463,
#  'am': 948,
#  'wales': 7342,
#  'ill': 3632,
#  'morrow': 4604,
#  'who': 7468,
#  'random': 5574,
#  'stupid': 6538,
#  'always': 946,
#  'sending': 6012,
#  'like': 4129,
#  'believe': 1319,
#  'those': 6846,
#  'pandy': 5068,
#  'mental': 4462,
#  've': 7244,
#  'down': 2446,
#  'not': 4839,
#  'sure': 6617,
#  'flavour': 2907,
#  'havent': 3380,
#  'add': 819,
#  'yet': 7664,
#  'something': 6304,
#  'sell': 6002,
#  'fast': 2799,
#  'easy': 2533,
#  'money': 4582,
#  'str8': 6500,
#  'each': 2517,
#  '8007': 650,
#  'classic': 1855,
#  'hit': 3464,
#  'polys': 5305,
#  '150p': 319,
#  '200p': 363,
#  'dont': 2425,
#  'touch': 6979,
#  'yeah': 7650,
#  'imma': 3644,
#  'cause': 1701,
#  'jay': 3820,
#  'wants': 7362,
#  'some': 6297,
#  'drugs': 2483,
#  '200': 357,
#  '08717895698': 137,
#  'mobstorequiz10ppm': 4562,
#  'another': 992,
#  'month': 4591,
#  'chocolate': 1820,
#  'weed': 7413,
#  'alcohol': 909,
#  'small': 6242,
#  'kid': 3952,
#  'boost': 1444,
#  'secret': 5976,
#  'energy': 2610,
#  'place': 5233,
#  'doin': 2411,
#  'girl': 3156,
#  'hope': 3512,
#  'okay': 4925,
#  'ure': 7187,
#  'away': 1181,
#  'trek': 7022,
#  'family': 2785,
#  'train': 6993,
#  'northampton': 4836,
#  'afraid': 859,
#  'staying': 6455,
#  'skyving': 6214,
#  'ho': 3482,
#  'around': 1084,
#  'wednesday': 7411,
#  'though': 6848,
#  'fancy': 2790,
#  'comedy': 1934,
#  'club': 1882,
#  'way': 7391,
#  'alex': 914,
#  'knows': 3984,
#  'his': 3462,
#  'birthday': 1376,
#  'fifteen': 2848,
#  'minutes': 4515,
#  'as': 1098,
#  'far': 2795,
#  'concerned': 1980,
#  'an': 969,
#  'actor': 814,
#  'evening': 2675,
#  'sleep': 6219,
#  'late': 4046,
#  'since': 6172,
#  'unemployed': 7135,
#  'moment': 4576,
#  'day': 2208,
#  'saturday': 5916,
#  'sao': 5899,
#  'mu': 4642,
#  'done': 2423,
#  '12': 294,
#  'b4u': 1192,
#  '27': 386,
#  '03': 13,
#  'marsms': 4384,
#  'onto': 4957,
#  'b4utele': 1193,
#  'discount': 2369,
#  'credit': 2097,
#  'customer': 2154,
#  'care': 1666,
#  '08717168528': 131,
#  'what': 7447,
#  'doing': 2412,
#  'talking': 6691,
#  'being': 1318,
#  'boy': 1480,
#  'missing': 4527,
#  'class': 1853,
#  'reunion': 5762,
#  'tape': 6699,
#  'pple': 5357,
#  'type': 7091,
#  'lor': 4223,
#  'help': 3422,
#  'hee': 3411,
#  'cos': 2047,
#  'noe': 4809,
#  'watch': 7378,
#  'infernal': 3690,
#  'affairs': 852,
#  'ask': 1104,
#  'along': 934,
#  'asking': 1108,
#  'shuhui': 6143,
#  'oso': 5003,
#  'themob': 6809,
#  'check': 1770,
#  'newest': 4768,
#  'selection': 5998,
#  'content': 2013,
#  'games': 3086,
#  'gossip': 3216,
#  'babes': 1198,
#  'sport': 6402,
#  'keep': 3931,
#  'fit': 2894,
#  'funky': 3066,
#  'wap': 7363,
#  '82468': 670,
#  'jazz': 3824,
#  'power': 5354,
#  'yoga': 7674,
#  'hip': 3459,
#  'hop': 3511,
#  'kb': 3928,
#  'yogasana': 7675,
#  '44': 501,
#  '7732584351': 633,
#  '3510i': 459,
#  'colour': 1925,
#  'deliveredtomorrow': 2257,
#  '300': 436,
#  'refilled': 5653,
#  'successfully': 6564,
#  'inr': 3708,
#  'decimal': 2229,
#  'keralacircle': 3938,
#  'prepaid': 5388,
#  'balance': 1216,
#  'rs': 5836,
#  'transaction': 7000,
#  'id': 3613,
#  'kr': 3995,
#  'were': 7436,
#  'outside': 5024,
#  'hours': 3539,
#  'whole': 7470,
#  'wake': 7340,
#  'started': 6442,
#  'post': 5338,
#  'l8r': 4003,
#  'chosen': 1828,
#  '350': 458,
#  'award': 1179,
#  'pls': 5262,
#  '09066364311': 239,
#  'collect': 1918,
#  'selected': 5997,
#  'valued': 7230,
#  'home': 3496,
#  'japanese': 3816,
#  'proverb': 5477,
#  'too': 6958,
#  'none': 4820,
#  'must': 4666,
#  'indian': 3683,
#  'version': 7253,
#  'finally': 2869,
#  'kerala': 3937,
#  'strike': 6513,
#  'against': 870,
#  'tell': 6740,
#  'headache': 3389,
#  'hour': 3537,
#  'sick': 6151,
#  'give': 3162,
#  'once': 4947,
#  'plus': 5266,
#  'she': 6073,
#  'grinule': 3265,
#  'greet': 3260,
#  'whenever': 7454,
#  'speak': 6358,
#  'banneduk': 1230,
#  '89555': 724,
#  'cost': 2049,
#  'textoperator': 6781,
#  'g696ga': 3076,
#  '18': 334,
#  'xxx': 7628,
#  'ke': 3929,
#  'qi': 5525,
#  'bored': 1448,
#  'izzit': 3796,
#  'suddenly': 6569,
#  'thk': 6840,
#  'hello': 3419,
#  'did': 2321,
#  'texting': 6780,
#  'decided': 2227,
#  'anything': 1013,
#  'invite': 3748,
#  'myself': 4679,
#  'guy': 3301,
#  'sells': 6004,
#  'mids': 4488,
#  'south': 6343,
#  'tampa': 6696,
#  'could': 2057,
#  'set': 6035,
#  'bears': 1281,
#  'pic': 5203,
#  'nick': 4780,
#  'tom': 6940,
#  'pete': 5177,
#  'dick': 2318,
#  'fact': 2763,
#  'types': 7092,
#  'try': 7042,
#  'pathaya': 5115,
#  'enketa': 2620,
#  'maraikara': 4369,
#  'pa': 5050,
#  'absolutly': 774,
#  'huh': 3568,
#  'also': 939,
#  'cannot': 1652,
#  'then': 6810,
#  'many': 4365,
#  'mistakes': 4533,
#  'find': 2872,
#  'sent': 6019,
#  'offline': 4912,
#  'anjola': 982,
#  'pass': 5103,
#  'dis': 2359,
#  'contacts': 2012,
#  'red': 5645,
#  'wid': 7481,
#  'blue': 1415,
#  'put': 5518,
#  'smile': 6253,
#  'face': 2760,
#  'purple': 5512,
#  'realy': 5612,
#  'hot': 3532,
#  'pink': 5223,
#  'swt': 6655,
#  'thnk': 6843,
#  'lyk': 4291,
#  'green': 3259,
#  'wana': 7356,
#  'yelow': 7657,
#  'wnt': 7539,
#  'bck': 1269,
#  'black': 1384,
#  'jealous': 3828,
#  'brown': 1541,
#  'nw': 4874,
#  'plz': 5268,
#  'giv': 3161,
#  'color': 1924,
#  '80488': 658,
#  'messages': 4475,
#  'until': 7167,
#  '31': 447,
#  'december': 2224,
#  '2005': 361,
#  'ok': 4924,
#  'taxi': 6710,
#  'ing': 3697,
#  'tuesday': 7055,
#  'cinema': 1839,
#  'maybe': 4418,
#  'reboot': 5620,
#  'seen': 5992,
#  'buzz': 1599,
#  'winner': 7505,
#  'specially': 6364,
#  '1000': 270,
#  'cash': 1688,
#  'holiday': 3491,
#  'flights': 2913,
#  'inc': 3662,
#  'live': 4168,
#  '0871277810810': 114,
#  'enjoying': 2619,
#  'brother': 1538,
#  'computerless': 1972,
#  'oreo': 4990,
#  'truffles': 7037,
#  'saw': 5924,
#  'both': 1455,
#  'battery': 1258,
#  'low': 4255,
#  'cultures': 2139,
#  'module': 4568,
#  'aathi': 758,
#  'lot': 4230,
#  'really': 5610,
#  'dun': 2504,
#  'bluff': 1418,
#  'leh': 4092,
#  'early': 2522,
#  'wanna': 7357,
#  'gym': 3305,
#  'harri': 3362,
#  'askd': 1105,
#  'question': 5534,
#  'answer': 995,
#  'login': 4194,
#  'dat': 2199,
#  'dad': 2173,
#  'fetching': 2836,
#  'sir': 6183,
#  'waiting': 7339,
#  'cbe': 1705,
#  'nowadays': 4852,
#  'showrooms': 6136,
#  'city': 1841,
#  'shaping': 6065,
#  'settled': 6039,
#  'school': 5940,
#  'year': 7651,
#  'wishin': 7514,
#  'meant': 4430,
#  'apology': 1029,
#  'goodnight': 3207,
#  'shall': 6060,
#  'book': 1436,
#  'chez': 1792,
#  'jules': 3889,
#  'half': 3324,
#  'eight': 2564,
#  'forwarded': 2985,
#  '448712404000': 507,
#  '08712404000': 108,
#  'immediately': 3646,
#  'able': 769,
#  'notice': 4844,
#  'few': 2838,
#  'weeks': 7419,
#  'anyway': 1016,
#  'plans': 5244,
#  'morning': 4601,
#  'aaooooright': 757,
#  'plane': 5239,
#  'end': 2601,
#  'bonus': 1433,
#  'caller': 1625,
#  'final': 2867,
#  '09064019788': 224,
#  'box42wr29c': 1476,
#  'opinion': 4969,
#  'about': 770,
#  'jada': 3804,
#  'kusruthi': 3999,
#  'lovable': 4241,
#  'silent': 6161,
#  'spl': 6388,
#  'character': 1746,
#  'matured': 4409,
#  'stylish': 6542,
#  'simple': 6167,
#  'gets': 3138,
#  'used': 7203,
#  'dumb': 2502,
#  'realize': 5607,
#  'aunty': 1155,
#  'cry': 2117,
#  'stuff': 6534,
#  'happens': 3349,
#  'everything': 2688,
#  'else': 2583,
#  'pushes': 5516,
#  'edge': 2544,
#  'underdtand': 7128,
#  'often': 4916,
#  'life': 4119,
#  'kinda': 3962,
#  'ad': 817,
#  'row': 5829,
#  'wiv': 7525,
#  'walked': 7346,
#  'pub': 5494,
#  'wanted': 7360,
#  'ps': 5484,
#  'grown': 3273,
#  'missed': 4525,
#  'alert': 911,
#  'these': 6817,
#  'numbers': 4864,
#  '07008009200': 21,
#  '09061701939': 203,
#  's89': 5866,
#  'real': 5604,
#  'bring': 1523,
#  'inner': 3702,
#  'tigress': 6881,
#  'representative': 5718,
#  'freephone': 3010,
#  '0808': 58,
#  '145': 312,
#  '4742': 515,
#  'between': 1344,
#  '9am': 747,
#  '11pm': 293,
#  '5000': 549,
#  'house': 3540,
#  'maid': 4331,
#  'murderer': 4661,
#  'coz': 2076,
#  'murdered': 4660,
#  'january': 3813,
#  'public': 5495,
#  'govt': 3227,
#  'instituitions': 3721,
#  'closed': 1874,
#  'including': 3668,
#  'office': 4908,
#  'understand': 7129,
#  'ta': 6667,
#  'tired': 6895,
#  'planning': 5243,
#  'social': 6285,
#  'services': 6032,
#  'inspection': 3713,
#  'nursery': 4865,
#  'spk': 6387,
#  'sn': 6270,
#  'ic': 3605,
#  'lol': 4200,
#  'play': 5247,
#  'doors': 2432,
#  'sometime': 6305,
#  'yo': 7673,
#  'coming': 1939,
#  'thursday': 6869,
#  'yay': 7648,
#  'cheers': 1780,
#  'alright': 937,
#  'hows': 3548,
#  'switch': 6653,
#  'dammit': 2178,
#  'alfie': 915,
#  'moon': 4596,
#  'children': 1804,
#  'song': 6315,
#  'mob': 4553,
#  'm8s': 4302,
#  'charity': 1751,
#  'nokias': 4816,
#  'zed': 7706,
#  '08701417012': 77,
#  'nt': 4855,
#  'chikku': 1800,
#  'habba': 3310,
#  'hw': 3592,
#  'abt': 775,
#  'imagine': 3639,
#  'sink': 6179,
#  'into': 3739,
#  'after': 863,
#  'through': 6858,
#  'paces': 5051,
#  'even': 2674,
#  'having': 3383,
#  'eat': 2534,
#  'while': 7464,
#  'feel': 2822,
#  'cage': 1610,
#  'cock': 1903,
#  'surrounded': 6626,
#  'water': 7384,
#  'reminding': 5693,
#  'owns': 5045,
#  'enjoy': 2616,
#  'cuck': 2134,
#  'appointment': 1042,
#  'connect': 1998,
#  'waheed': 7334,
#  'fathima': 2805,
#  'frens': 3015,
#  'alone': 933,
#  'wif': 7483,
#  'mum': 4652,
#  'sis': 6185,
#  'guess': 3289,
#  'somebody': 6299,
#  ...}

# %%
X_train_np = X_train_cv.toarray()
X_train_np[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
np.where(X_train_np[0]!=0)
# Out:
# (array([ 202,  302,  734, 1064, 1617, 1844, 1906, 2010, 2459, 3283, 3377,
#         3906, 4043, 4954, 5430, 6137, 6795, 6921, 7044, 7189, 7226, 7396,
#         7417, 7547, 7678]),)

# %%
X_train[:4]
# Out:
# 3807    URGENT! We are trying to contact you. Last wee...
# 1981                               Sorry, I'll call later
# 4746    Camera - You are awarded a SiPix Digital Camer...
# 4099       I think just yourself …Thanks and see you tomo
# Name: Message, dtype: object

# %%
X_train_np[0][1064]
# Out:
# 1

# %%
# Train Naive Bayes Model

from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train_cv, y_train)
# Out:
# MultinomialNB()

# %%
X_test
# Out:
# 1466    YOU 07801543489 are guaranteed the latests Nok...
# 5384    How are you babes. Hope your doing ok. I had a...
# 4434    Can u look 4 me in da lib i got stuff havent f...
# 3411    Joy's father is John. Then John is the ____ of...
# 2231    Hey... Thk we juz go accordin to wat we discus...
#                               ...
# 2718                                       Okie.. Thanx..
# 4743                Ya very nice. . .be ready on thursday
# 4579    Urgent! call 09066350750 from your landline. Y...
# 252     Wen ur lovable bcums angry wid u, dnt take it ...
# 1127    Not tonight mate. Catching up on some sleep. T...
# Name: Message, Length: 1115, dtype: object

# %%
X_test_cv = v.transform(X_test)

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test_cv)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       987
#            1       0.98      0.97      0.97       128
#
#     accuracy                           0.99      1115
#    macro avg       0.99      0.98      0.98      1115
# weighted avg       0.99      0.99      0.99      1115

# %%
emails = [
    'Hey mohan, can we get together to watch footbal game tomorrow?',
    'Upto 20% discount on parking, exclusive offer just for you. Dont miss this reward!'
]

emails_count = v.transform(emails)
model.predict(emails_count)
# Out:
# array([0, 1])

# %%
# Train the model using sklearn pipeline and reduce number of lines of code

# %%
from sklearn.pipeline import Pipeline

clf = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('nb', MultinomialNB())
])

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()), ('nb', MultinomialNB())])

# %%
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       987
#            1       0.98      0.97      0.97       128
#
#     accuracy                           0.99      1115
#    macro avg       0.99      0.98      0.98      1115
# weighted avg       0.99      0.99      0.99      1115
